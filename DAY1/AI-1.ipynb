# %%
import sys
sys.version
# Out:
# '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\karth'

# %% [markdown]
# ![image.png](attachment:5ca5f718-d44c-46ef-a557-0fd895bb024f.png)

# %%
! python p1.py
# Out:
# Hello

# %%
! <commandline task> <== In jupyter cell

# %%
print("Hello")
# Out:
# Hello

# %%
var = 10
print(var)
# Out:
# 10

# %%
var = 20

# %%
print(var)
# Out:
# 20

# %%
import time
time.sleep(15)
print("OK")
# Out:
# OK

# %%
! pip install requests bs4

# %%
fobj = open('filename','r')

# %%
! pip install -r requirements.txt

# %%
import langchain

# %%
! pip show langchain
# Out:
# Name: langchain
# Version: 1.2.7
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: C:\ProgramData\anaconda3\Lib\site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:
# WARNING: Ignoring invalid distribution ~angchain-community (C:\ProgramData\anaconda3\Lib\site-packages)

# %%
from langchain_ollama import OllamaLLM

# %%
print(OllamaLLM)
# Out:
# <class 'langchain_ollama.llms.OllamaLLM'>

# %%
langchain_ollama/
           |-------->llms.py
                          |------->class OllamaLLM

OllamaLLM(model="model_Name") ->obj
                      |<---- refer in commandline -> ollama list 

obj.invoke('UserQuery') -->Result

# %%
llm_obj = OllamaLLM(model="gemma2:2b")

# %%
llm_obj.invoke("What is Langchain Explain In oneline?")
# Out:
# 'LangChain simplifies building LLM-powered applications by providing a modular framework for chains, memories, and prompts. \n'

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ # ===> same as env command in commandline 
os.getenv('GROQ_API_KEY')
# Out:
# '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'

# %%
from langchain_groq import ChatGroq

# %%
llm_obj = ChatGroq(model="llama-3.1-8b-instant",api_key=os.getenv('GROQ_API_KEY'))

# %%
llm_obj.invoke("What is langchain explain in oneline?")
# Out:
# AIMessage(content='LangChain is an open-source framework for building large language models (LLMs) that enables developers to create, combine, and execute complex AI workflows, bridging the gap between LLMs and traditional software development.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 44, 'prompt_tokens': 44, 'total_tokens': 88, 'completion_time': 0.126959556, 'prompt_time': 0.002657326, 'queue_time': 0.051085934, 'total_time': 0.129616882}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1df9-1157-73e1-b4a1-e02e293bec15-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 44, 'output_tokens': 44, 'total_tokens': 88})

# %%
response = llm_obj.invoke("What is langchain explain in oneline?")
print(response.content)
# Out:
# LangChain is an open-source framework for building large language models (LLMs) and multimodal applications, allowing developers to create custom LLMs and integrate them with other tools and services.

# %%
llm_obj.invoke('User input Query') --> AI_Response <or> (model_Response) 

UserQuery --- plain text - english - ordinary string 
|
Input-Validation
|
Prompt Construction
|
Tokenization
|
Model Inference
|
Decoding
|
Post-processing
|
LLM Reponse Object

####################
Prompt Construction
 |-> Text + jinja2 Template (DynamicValue) {{placehoder}} -- rules

    system prompt -- AI Role - How AI(llm) to behave/response to user query
    user prompt  -- User input

|
User Query: "what is langchain explain oneline?"
    |
    Token => ["what","is","langchain","explain","oneline","?"]
               |       |
      TokenID:[2061,319,456,,....] 
  |
  |
EmbeddingLayer(Transformer)
                |->Model Inference 

Generated tokens -->highest probability 
| [1012,567,345,45] ..
Decoding (Token -->Text)
                     |---->-->--

# %%
#############  End of DAY1 ##################
